# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/ronaldolagepessoa/data_science/master/dados/bmw.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
dfs = df[df.model.str.contains('Series')]
dfs.groupby('model').mean()
# Out:
#                   year         price       mileage         tax        mpg  \
# model
#  1 Series  2016.608939  15821.670391  27916.201117  108.882682  57.673083
#  2 Series  2017.799837  19539.371847  17042.604557  127.957689  55.863222
#  3 Series  2016.680311  19880.857962  31858.368400  123.526402  58.062996
#  4 Series  2017.483417  22498.418090  21786.536683  132.829146  55.511357
#  5 Series  2016.884470  22537.428030  30761.406250  126.250000  62.092614
#  6 Series  2015.972222  24354.370370  31685.212963  180.601852  46.393519
#  7 Series  2017.103774  36934.320755  23687.273585  161.792453  46.226415
#  8 Series  2019.282051  63997.794872   3832.897436  145.897436  33.533333
#
#            engineSize
# model
#  1 Series    1.884865
#  2 Series    1.873474
#  3 Series    2.183095
#  4 Series    2.243216
#  5 Series    2.225473
#  6 Series    2.938889
#  7 Series    3.136792
#  8 Series    3.251282

# %%
price = dfs.groupby('model').count()['price']
price
# Out:
# model
#  1 Series    1969
#  2 Series    1229
#  3 Series    2443
#  4 Series     995
#  5 Series    1056
#  6 Series     108
#  7 Series     106
#  8 Series      39
# Name: price, dtype: int64

# %%
df[df.model.str.contains('Series')].price.hist()
# Out:
# <AxesSubplot:>

# %%
df.groupby('transmission').describe()['price']
# Out:
#                count          mean           std     min       25%      50%  \
# transmission
# Automatic     3588.0  22419.023969  11189.971319  1200.0  14973.75  19490.0
# Manual        2527.0  14637.451128   5725.267639  1445.0  10703.00  13500.0
# Semi-Auto     4666.0  27359.747964  11406.820313  5299.0  19795.75  24990.0
#
#                    75%       max
# transmission
# Automatic     27500.00   99950.0
# Manual        17533.50   46000.0
# Semi-Auto     31647.75  123456.0

# %%
df.groupby('model').describe()['price']
# Out:
#             count          mean           std      min       25%      50%  \
# model
#  1 Series  1969.0  15821.670391   5957.713264   1500.0  11399.00  14800.0
#  2 Series  1229.0  19539.371847   6080.250595   5895.0  15342.00  19980.0
#  3 Series  2443.0  19880.857962   8394.421652   1200.0  13798.00  18299.0
#  4 Series   995.0  22498.418090   6401.674559   8500.0  17500.00  21975.0
#  5 Series  1056.0  22537.428030   8729.997867   1595.0  14500.00  22996.5
#  6 Series   108.0  24354.370370   8590.169421   4995.0  18665.25  22854.0
#  7 Series   106.0  36934.320755  14491.225974   4995.0  26037.25  37224.5
#  8 Series    39.0  63997.794872   8307.191251  51980.0  58995.00  61898.0
#  M2          21.0  43140.333333   6197.695921  23495.0  42110.00  44990.0
#  M3          27.0  30229.777778  12689.168538  10999.0  17800.00  31000.0
#  M4         125.0  43274.232000  10920.580243  26499.0  34995.00  43480.0
#  M5          29.0  57760.000000  19403.790552  23490.0  36494.00  63980.0
# ...

# %%
dfs.groupby(['model','transmission']).describe()['price']
# Out:
#                          count          mean           std      min       25%  \
# model     transmission
#  1 Series Automatic      361.0  16777.692521   5639.712750   3500.0  12999.00
#           Manual        1103.0  13433.198549   4820.031480   1500.0  10225.00
#           Semi-Auto      505.0  20355.057426   5598.903610   9444.0  15998.00
#  2 Series Automatic      303.0  19274.306931   5076.883171   8995.0  15083.50
#           Manual         412.0  16873.378641   5026.203138   5895.0  12584.25
#           Semi-Auto      514.0  21832.570039   6485.693290  10998.0  17995.75
#  3 Series Automatic      830.0  18686.009639   8097.494388   1200.0  13491.25
#           Manual         538.0  13693.000000   6250.287928   1445.0   9940.50
#           Semi-Auto     1075.0  23900.199070   7322.811188   5695.0  18492.50
#  4 Series Automatic      376.0  21452.579787   6433.994887  10195.0  16495.00
#           Manual         122.0  17262.795082   5156.514605   8500.0  13999.00
# ...

# %%
df.groupby('year').count().sort_values(by='price', ascending=False).head()
# Out:
#       model  price  transmission  mileage  fuelType   tax   mpg  engineSize
# year
# 2019   3485   3485          3485     3485      3485  3485  3485        3485
# 2016   1882   1882          1882     1882      1882  1882  1882        1882
# 2017   1721   1721          1721     1721      1721  1721  1721        1721
# 2015    922    922           922      922       922   922   922         922
# 2018    848    848           848      848       848   848   848         848

# %%
df[df.year==2019].price.mean()
# Out:
# 31025.864275466283

# %%
df.groupby('model').count().sort_values(by='price',ascending=False).head()
# Out:
#            year  price  transmission  mileage  fuelType   tax   mpg  \
# model
#  3 Series  2443   2443          2443     2443      2443  2443  2443
#  1 Series  1969   1969          1969     1969      1969  1969  1969
#  2 Series  1229   1229          1229     1229      1229  1229  1229
#  5 Series  1056   1056          1056     1056      1056  1056  1056
#  4 Series   995    995           995      995       995   995   995
#
#            engineSize
# model
#  3 Series        2443
#  1 Series        1969
#  2 Series        1229
#  5 Series        1056
#  4 Series         995

# %%
df[df.model.str.contains('3 Series')].price.mean()
# Out:
# 19880.857961522717

# %%
df[df.model.str.contains('3 Series')].price.mean()
# Out:
# 19880.857961522717

# %%
df.groupby(['model','year']).count().sort_values(by='price',ascending=False)
# Out:
#                 price  transmission  mileage  fuelType  tax  mpg  engineSize
# model     year
#  3 Series 2019    658           658      658       658  658  658         658
#  2 Series 2019    488           488      488       488  488  488         488
#  1 Series 2019    454           454      454       454  454  454         454
#           2016    434           434      434       434  434  434         434
#           2017    414           414      414       414  414  414         414
# ...               ...           ...      ...       ...  ...  ...         ...
#  X6       2011      1             1        1         1    1    1           1
#  5 Series 2004      1             1        1         1    1    1           1
#           2003      1             1        1         1    1    1           1
#           2000      1             1        1         1    1    1           1
#  1 Series 2001      1             1        1         1    1    1           1
#
# [222 rows x 7 columns]

# %%
filtro = ((df.model.str.contains('3 Series'))&(df.year==2019))
df[filtro].price.mean()
# Out:
# 28366.767477203648
