# %%
import pandas as pd

housing = pd.read_csv('Dados/housing_ok.csv')
housing.head()
# Out:
#           bairro          endereco  quartos    tipo      preco  \
# 0    Collingwood    2/79 Oxford St        2  kitnet   855000.0
# 1        Fitzroy   52 Nicholson St        4    casa  3310000.0
# 2      Parkville       152 Park Dr        2    casa  2200000.0
# 3        Carlton    100 Faraday St        2    casa  1010000.0
# 4  Fitzroy North  470 Brunswick St        2    casa   860000.0
#
#    distancia_aeroporto     cep  banheiros  vagas  area_terreno  \
# 0                  1.6  3066.0          1      1        2886.0
# 1                  1.6  3065.0          4      2         337.0
# 2                  2.6  3052.0          2      1         190.0
# 3                  1.8  3053.0          1      0         101.0
# 4                  3.5  3068.0          1      0         104.0
#
#    area_construida  ano_construcao  latitude  longitude
# 0            122.0          1830.0  -37.8042   144.9845
# 1            291.0          1854.0  -37.8052   144.9739
# 2            172.0          1875.0  -37.7928   144.9575
# 3             60.0          1880.0  -37.7989   144.9713
# 4             70.0          1880.0  -37.7927   144.9796

# %%
housing.groupby(by='tipo').mean()
# Out:
#               quartos         preco  distancia_aeroporto          cep  \
# tipo
# apartamento  2.946058  8.881973e+05             9.865145  3085.265560
# casa         3.295434  1.352434e+06             9.073993  3089.119517
# kitnet       2.128852  6.067495e+05             8.974510  3099.084034
#
#              banheiros     vagas  area_terreno  area_construida  \
# tipo
# apartamento   1.858921  1.514523    384.651452       142.610788
# casa          1.667413  1.713071    515.550582       163.590304
# kitnet        1.170868  1.176471    830.633053        86.175378
#
#              ano_construcao   latitude   longitude
# tipo
# apartamento     2000.149378 -37.802300  144.980269
# casa            1947.431065 -37.803816  144.985277
# kitnet          1982.086835 -37.810230  144.992512

# %%
housing.groupby(by=['tipo', 'quartos']).preco.max()
# Out:
# tipo         quartos
# apartamento  1           345000.0
#              2          1540000.0
#              3          2700000.0
#              4          2900000.0
#              5           980000.0
# casa         1          1435000.0
#              2          2875000.0
#              3          6250000.0
#              4          5700000.0
#              5          8000000.0
#              6          6500000.0
#              7          2600000.0
#              8          2950000.0
# kitnet       1           600000.0
#              2          1260000.0
#              3          2460000.0
#              4          1650000.0
# Name: preco, dtype: float64

# %%
housing.groupby(by=['tipo', 'quartos']).preco.max().plot.bar()
# Out:
# <AxesSubplot:xlabel='tipo,quartos'>

# %%
housing.groupby(by=['tipo', 'quartos']).preco.describe()
# Out:
#                       count          mean           std        min        25%  \
# tipo        quartos
# apartamento 1           1.0  3.450000e+05           NaN   345000.0   345000.0
#             2          57.0  7.092614e+05  2.407493e+05   380000.0   550500.0
#             3         139.0  8.819399e+05  3.236793e+05   430000.0   697000.0
#             4          42.0  1.168286e+06  4.698303e+05   600000.0   882250.0
#             5           2.0  8.125000e+05  2.368808e+05   645000.0   728750.0
# casa        1           8.0  8.517750e+05  3.317692e+05   260000.0   739925.0
#             2         343.0  9.879258e+05  3.506039e+05   365000.0   758750.0
#             3        1065.0  1.167121e+06  5.302197e+05   305000.0   796000.0
#             4         643.0  1.648079e+06  7.766668e+05   131000.0  1100000.0
#             5         156.0  2.135564e+06  1.001402e+06   605000.0  1488750.0
#             6          14.0  2.205857e+06  1.474685e+06   725000.0  1436250.0
#             7           3.0  1.701667e+06  7.794282e+05  1205000.0  1252500.0
#             8           2.0  1.915500e+06  1.463004e+06   881000.0  1398250.0
# kitnet      1          41.0  3.768049e+05  8.659495e+04   185000.0   325000.0
#             2         231.0  5.871496e+05  1.721690e+05   266000.0   470500.0
#             3          83.0  7.605542e+05  2.945745e+05   400000.0   552500.0
#             4           2.0  1.201500e+06  6.342748e+05   753000.0   977250.0
#
#                            50%        75%        max
# tipo        quartos
# apartamento 1         345000.0   345000.0   345000.0
#             2         678000.0   800000.0  1540000.0
#             3         825000.0   970000.0  2700000.0
#             4        1102500.0  1311250.0  2900000.0
#             5         812500.0   896250.0   980000.0
# casa        1         885500.0   956875.0  1435000.0
#             2         910000.0  1178500.0  2875000.0
#             3        1060000.0  1425000.0  6250000.0
#             4        1500000.0  2000500.0  5700000.0
#             5        1917500.0  2600000.0  8000000.0
#             6        1783000.0  2381250.0  6500000.0
#             7        1300000.0  1950000.0  2600000.0
#             8        1915500.0  2432750.0  2950000.0
# kitnet      1         370000.0   426500.0   600000.0
#             2         580000.0   660000.0  1260000.0
#             3         725000.0   877500.0  2460000.0
#             4        1201500.0  1425750.0  1650000.0

# %%
df = pd.read_csv('Dados/NationalNames.csv')
df.head()
# Out:
#    Id       Name    Year Gender   Count
# 0   1       Mary  1880.0      F  7065.0
# 1   2       Anna  1880.0      F  2604.0
# 2   3       Emma  1880.0      F  2003.0
# 3   4  Elizabeth  1880.0      F  1939.0
# 4   5     Minnie  1880.0      F  1746.0

# %%
df[df.Name.str[0]=='R'].head()
# Out:
#       Id     Name    Year Gender  Count
# 29    30     Rose  1880.0      F  700.0
# 51    52     Rosa  1880.0      F  507.0
# 91    92  Rebecca  1880.0      F  236.0
# 92    93     Ruth  1880.0      F  234.0
# 108  109   Rachel  1880.0      F  166.0

# %%
df.groupby(df.Name.str[0]).Count.sum()
# Out:
# Name
# A    1412794.0
# B     625278.0
# C    1067528.0
# D     549447.0
# E    1793853.0
# F     738527.0
# G     743757.0
# H     977058.0
# I     342705.0
# J    1569854.0
# K     184662.0
# L    1288376.0
# M    2348366.0
# N     319401.0
# O     245452.0
# P     337652.0
# Q       4001.0
# R    1063018.0
# S     525058.0
# T     306284.0
# U       7678.0
# V     379793.0
# W     749211.0
# X        112.0
# Y       7913.0
# Z      30681.0
# Name: Count, dtype: float64

# %%
df[df.Name.str.len()==3].head()
# Out:
#     Id Name    Year Gender   Count
# 6    7  Ida  1880.0      F  1472.0
# 32  33  Ada  1880.0      F   652.0
# 40  41  Eva  1880.0      F   614.0
# 56  57  May  1880.0      F   462.0
# 70  71  Mae  1880.0      F   344.0

# %%
df1 = df.dropna()
df1[df.Name.str.contains('x').dropna()].head()
# Out:
#         Id       Name    Year Gender  Count
# 195    196      Roxie  1880.0      F   62.0
# 436    437      Dixie  1880.0      F   15.0
# 623    624    Roxanna  1880.0      F    9.0
# 933    934      Texas  1880.0      F    5.0
# 1014  1015  Alexander  1880.0      M  211.0

# %%
df = pd.read_csv('Dados/drugs.csv')
df.head()
# Out:
#        Date  Antinflam  Analg  Anxio  Hypnotics  Obst_airway  Antihis
# 0  1/2/2014        0.0    3.4    7.0        0.0          0.0      2.0
# 1  1/3/2014        8.0    4.4   16.0        0.0         20.0      4.0
# 2  1/4/2014        2.0    6.5   10.0        0.0          9.0      1.0
# 3  1/5/2014        4.0    7.0    8.0        0.0          3.0      0.0
# 4  1/6/2014        5.0    4.5   16.0        2.0          6.0      2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2106 non-null   object
#  1   Antinflam    2106 non-null   float64
#  2   Analg        2106 non-null   float64
#  3   Anxio        2106 non-null   float64
#  4   Hypnotics    2106 non-null   float64
#  5   Obst_airway  2106 non-null   float64
#  6   Antihis      2106 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 115.3+ KB

# %%
pd.to_datetime(df.Date)
# Out:
# 0      2014-01-02
# 1      2014-01-03
# 2      2014-01-04
# 3      2014-01-05
# 4      2014-01-06
#           ...
# 2101   2019-10-04
# 2102   2019-10-05
# 2103   2019-10-06
# 2104   2019-10-07
# 2105   2019-10-08
# Name: Date, Length: 2106, dtype: datetime64[ns]

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2106 non-null   datetime64[ns]
#  1   Antinflam    2106 non-null   float64
#  2   Analg        2106 non-null   float64
#  3   Anxio        2106 non-null   float64
#  4   Hypnotics    2106 non-null   float64
#  5   Obst_airway  2106 non-null   float64
#  6   Antihis      2106 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 115.3 KB

# %%
df[df.Date.dt.year==2015]
# Out:
#           Date  Antinflam  Analg  Anxio  Hypnotics  Obst_airway  Antihis
# 364 2015-01-01       0.00    0.0    0.0        0.0         0.00      0.0
# 365 2015-01-02       6.00    4.9   13.0        0.0         6.25      2.0
# 366 2015-01-03       9.00    6.0   11.0        3.0         0.00      4.0
# 367 2015-01-04       4.68    3.5    4.0        0.0         2.00      1.0
# 368 2015-01-05       2.34    1.0   14.0        0.0        16.00      3.0
# ..         ...        ...    ...    ...        ...          ...      ...
# 724 2015-12-27       5.33    5.2    4.0        0.0        14.00      4.6
# 725 2015-12-28       4.00    9.2   18.0        3.0        26.00      1.0
# 726 2015-12-29      10.67    2.0    9.0        0.0         2.00      3.0
# 727 2015-12-30       6.66    2.0   12.0        0.0         4.00      2.0
# 728 2015-12-31       7.66    7.6   18.0        0.0         6.00      1.0
#
# [365 rows x 7 columns]

# %%
df.groupby(df.Date.dt.month).mean()
# Out:
#       Antinflam     Analg      Anxio  Hypnotics  Obst_airway   Antihis
# Date
# 1      5.022336  4.636329  10.988919   0.790090     6.835980  1.617568
# 2      4.999527  4.679024   9.024803   0.563116     6.896943  1.703314
# 3      4.912097  3.993844   8.265591   0.623656     6.290323  3.184624
# 4      5.117944  3.711944   7.852222   0.477778     5.771528  4.703889
# 5      4.846183  3.715806   7.482796   0.607527     5.006944  5.002957
# 6      4.714778  3.753944   7.913889   0.588889     4.350000  4.436889
# 7      5.207921  3.483333   8.298925   0.478495     2.956989  3.358763
# 8      5.428333  3.477151   9.086022   0.612903     3.102151  2.689785
# 9      5.004889  3.374167   9.240556   0.522222     4.402315  2.573333
# 10     4.972301  3.950844   9.471754   0.525307     7.208589  1.954709
# 11     5.225644  4.193667   9.302444   0.673333     6.226667  1.569333
# 12     4.957419  3.682843   9.576344   0.670968     7.916129  1.356323

# %%
df.groupby(df.Date.dt.month).mean().plot.bar(figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.groupby(df.Date.dt.weekday).mean().plot.bar(figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def perto_ou_longe(x):
    if x > 3.5:
        return 'longe'
    else:
        return 'perto'
    
housing.distancia_aeroporto.apply(perto_ou_longe)
# Out:
# 0       perto
# 1       perto
# 2       perto
# 3       perto
# 4       perto
#         ...
# 2827    longe
# 2828    longe
# 2829    longe
# 2830    longe
# 2831    longe
# Name: distancia_aeroporto, Length: 2832, dtype: object

# %%
housing['perto_ou_longe'] = housing.distancia_aeroporto.apply(perto_ou_longe)
housing.head()
# Out:
#           bairro          endereco  quartos    tipo      preco  \
# 0    Collingwood    2/79 Oxford St        2  kitnet   855000.0
# 1        Fitzroy   52 Nicholson St        4    casa  3310000.0
# 2      Parkville       152 Park Dr        2    casa  2200000.0
# 3        Carlton    100 Faraday St        2    casa  1010000.0
# 4  Fitzroy North  470 Brunswick St        2    casa   860000.0
#
#    distancia_aeroporto     cep  banheiros  vagas  area_terreno  \
# 0                  1.6  3066.0          1      1        2886.0
# 1                  1.6  3065.0          4      2         337.0
# 2                  2.6  3052.0          2      1         190.0
# 3                  1.8  3053.0          1      0         101.0
# 4                  3.5  3068.0          1      0         104.0
#
#    area_construida  ano_construcao  latitude  longitude perto_ou_longe
# 0            122.0          1830.0  -37.8042   144.9845          perto
# 1            291.0          1854.0  -37.8052   144.9739          perto
# 2            172.0          1875.0  -37.7928   144.9575          perto
# 3             60.0          1880.0  -37.7989   144.9713          perto
# 4             70.0          1880.0  -37.7927   144.9796          perto

# %%
housing.eval('razao_area = area_construida / area_terreno', inplace=True)
housing.head()
# Out:
#           bairro          endereco  quartos    tipo      preco  \
# 0    Collingwood    2/79 Oxford St        2  kitnet   855000.0
# 1        Fitzroy   52 Nicholson St        4    casa  3310000.0
# 2      Parkville       152 Park Dr        2    casa  2200000.0
# 3        Carlton    100 Faraday St        2    casa  1010000.0
# 4  Fitzroy North  470 Brunswick St        2    casa   860000.0
#
#    distancia_aeroporto     cep  banheiros  vagas  area_terreno  \
# 0                  1.6  3066.0          1      1        2886.0
# 1                  1.6  3065.0          4      2         337.0
# 2                  2.6  3052.0          2      1         190.0
# 3                  1.8  3053.0          1      0         101.0
# 4                  3.5  3068.0          1      0         104.0
#
#    area_construida  ano_construcao  latitude  longitude perto_ou_longe  \
# 0            122.0          1830.0  -37.8042   144.9845          perto
# 1            291.0          1854.0  -37.8052   144.9739          perto
# 2            172.0          1875.0  -37.7928   144.9575          perto
# 3             60.0          1880.0  -37.7989   144.9713          perto
# 4             70.0          1880.0  -37.7927   144.9796          perto
#
#    razao_area
# 0    0.042273
# 1    0.863501
# 2    0.905263
# 3    0.594059
# 4    0.673077

# %%
df = pd.read_csv('Dados/exemplo_pivot.csv')
df
# Out:
#        nome disciplina  nota_final  freq
# 0   Ronaldo          A          10  1.00
# 1      Hugo          A           9  0.90
# 2    Victor          A          10  0.95
# 3      João          A           8  0.90
# 4   Gabriel          A           7  0.80
# 5   Ronaldo          B           9  0.85
# 6      Hugo          B           8  0.80
# 7    Victor          B           8  0.75
# 8      João          B          10  0.90
# 9   Gabriel          B          10  0.90
# 10  Ronaldo          C           9  1.00
# 11     Hugo          C           9  1.00
# 12   Victor          C           9  0.75
# 13     João          C           8  0.80
# 14  Gabriel          C           9  0.90

# %%
df.pivot(index='nome', columns='disciplina', values='nota_final')
# Out:
# disciplina   A   B  C
# nome
# Gabriel      7  10  9
# Hugo         9   8  9
# João         8  10  8
# Ronaldo     10   9  9
# Victor      10   8  9

# %%
df.pivot(index='nome', columns='disciplina', values='freq')
# Out:
# disciplina     A     B     C
# nome
# Gabriel     0.80  0.90  0.90
# Hugo        0.90  0.80  1.00
# João        0.90  0.90  0.80
# Ronaldo     1.00  0.85  1.00
# Victor      0.95  0.75  0.75

# %%
df.pivot(index='nome', columns='disciplina', values='freq').transpose()
# Out:
# nome        Gabriel  Hugo  João  Ronaldo  Victor
# disciplina
# A               0.8   0.9   0.9     1.00    0.95
# B               0.9   0.8   0.9     0.85    0.75
# C               0.9   1.0   0.8     1.00    0.75
